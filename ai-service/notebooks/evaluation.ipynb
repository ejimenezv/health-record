# %% [markdown]
# # RAGAS Evaluation — MedRecord AI Service
#
# Placeholder notebook. RAGAS-based evaluation of the Spanish medical RAG pipeline is implemented in a later prompt.
#
# Required metrics (BSG): faithfulness, answer relevancy, context precision, context recall.

# %%
# TODO: load eval dataset, run RAG pipeline, compute RAGAS metrics, write report to ../reports/
print('evaluation notebook placeholder')
